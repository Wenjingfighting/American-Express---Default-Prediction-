# %% [markdown]
# This model is based on https://www.kaggle.com/code/kunheekimkr/amex-lgbm-gpu-starter-0-795.

# %%
# LOAD LIBRARIES
import pandas as pd, numpy as np # CPU libraries
import cupy, cudf # GPU libraries
import matplotlib.pyplot as plt, gc, os
from tqdm.auto import tqdm

print('RAPIDS version',cudf.__version__)
# Out:
# RAPIDS version 21.10.01

# %%
# VERSION NAME FOR SAVED MODEL FILES
VER = 1

# TRAIN RANDOM SEED
SEED = 42

# FILL NAN VALUE
NAN_VALUE = -127 # will fit in int8

# FOLDS PER MODEL
FOLDS = 5

# %% [markdown]
# ## Process and Feature Engineer Train Data

# %% [markdown]
# According to the analysis of data wrangling we remove the following features:
#
# 1) according to missing value analysis: 'B_29' and 'D-82'
#
# 2) according to correlation analysis: 'D_75','D_74','D_119','D_77','D_104','D_143','D_141','S_7','S_24','B_33','B_23','B_15','B_37','B_11'
# 3) according to distribution of non-categorical features analysis: 'D_87','D_61','D_123','D_69','D_106','D_65','D_137','D_109','D_49','D_135','D_50','D_71','D_93','D_138','B_40','B_10','B_6','B_12','B_27','B_13','B_26','B_5','B_21','B_31','B_36'

# %%
def read_file(path = '', usecols = None):
    # LOAD DATAFRAME
    if usecols is not None: df = cudf.read_parquet(path, columns=usecols)
    else: df = cudf.read_parquet(path)
    # REDUCE DTYPE FOR CUSTOMER AND DATE
    df['customer_ID'] = df['customer_ID'].str[-16:].str.hex_to_int().astype('int64')
    df.S_2 = cudf.to_datetime( df.S_2 )
    # SORT BY CUSTOMER AND DATE (so agg('last') works correctly)
    #df = df.sort_values(['customer_ID','S_2'])
    #df = df.reset_index(drop=True)
    df = df.drop(columns=['B_29','D_82','D_75','D_74','D_119','D_77','D_104','D_143','D_141','S_7','S_24','B_33',
                   'B_23','B_15','B_37','B_11','D_87','D_61','D_123','D_69','D_106','D_65','D_137','D_109',
                   'D_49','D_135','D_50','D_71','D_93','D_138','B_40','B_10','B_6','B_12','B_27','B_13',
                   'B_26','B_5','B_21','B_31','B_36'])
   # FILL NAN
    df = df.fillna(NAN_VALUE) 

    #pred_1 = U[['customer_ID','target','pre_target']]
    print('shape of data:', df.shape)
    
    return df

# %%
def get_difference(data, num_features):
    second_last = data.groupby(['customer_ID'])[num_features].nth(-2)
    last = data.groupby(['customer_ID'])[num_features].last()
    returned_df = last - second_last
    returned_df.columns = [col + '_diff1' for col in returned_df.columns]
    returned_df.reset_index(inplace = True)
    return returned_df


def process_and_feature_engineer(df):
    # FEATURE ENGINEERING FROM 
    # https://www.kaggle.com/code/huseyincot/amex-agg-data-how-it-created
    all_cols = [c for c in list(df.columns) if c not in ['customer_ID','S_2']]
    cat_features = ["B_30","B_38","D_114","D_116","D_117","D_120","D_126","D_63","D_64","D_66","D_68"]
    num_features = [col for col in all_cols if col not in cat_features]

    test_num_agg = df.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]
    test_num_agg.reset_index(inplace = True)

    # Lag Features
    for col in test_num_agg:
        if 'last' in col and col.replace('last', 'mean') in test_num_agg:
            test_num_agg[col + '_lag_sub'] = test_num_agg[col] - test_num_agg[col.replace('last', 'mean')]
            test_num_agg[col + '_lag_div'] = test_num_agg[col] / (test_num_agg[col.replace('last', 'mean')] + 0.001)

    test_cat_agg = df.groupby("customer_ID")[cat_features].agg(['count','last', 'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]
    test_cat_agg.reset_index(inplace = True)
    
    #cols = list(test_num_agg.dtypes[test_num_agg.dtypes == 'float64'].index)
    #for col in tqdm(cols):
    #    test_num_agg[col] = test_num_agg[col].astype(np.float32)
    ## Transform int64 columns to int32
    #cols = list(test_cat_agg.dtypes[test_cat_agg.dtypes == 'int64'].index)
    #for col in tqdm(cols):
    #    test_cat_agg[col] = test_cat_agg[col].astype(np.int32)
    # Get the difference
    df_diff = get_difference(df, num_features)
    df = test_num_agg.merge(test_cat_agg, how = 'inner', on = 'customer_ID').merge(df_diff, how = 'inner', on = 'customer_ID')
    #print(test_num_agg['customer_ID'].head())
    #print(test_cat_agg['customer_ID'].head())
    #print(df_diff['customer_ID'].head())
    del test_num_agg, test_cat_agg
    df.set_index('customer_ID',inplace = True)
    print('shape after engineering', df.shape )
    
    
    #cols = list(df.dtypes[df.dtypes == 'float64'].index)
    #for col in tqdm(cols):
    #    df[col] = df[col].astype(np.float32)
    #cols = list(df.dtypes[df.dtypes == 'int64'].index)
    #cols = [col for col in cols if col != 'customer_ID']
    #for col in tqdm(cols):
    #    df[col] = df[col].astype(np.int32)
    #cols = list(df.dtypes[df.dtypes == 'object'].index)
    #cols = [col for col in cols if col != 'customer_ID']
    #for col in tqdm(cols):
    #    df[col] = df[col].astype('category')
    return df

# %%
print('Reading train data...')
TRAIN_PATH = '../input/amex-data-integer-dtypes-parquet-format/train.parquet'
train = read_file(path = TRAIN_PATH)
# Out:
# Reading train data...
# shape of data: (5531451, 149)

# %%
train = process_and_feature_engineer(train)
# Out:
# shape after engineering (458913, 1121)

# %%
targets = cudf.read_csv('../input/amex-default-prediction/train_labels.csv')
targets['customer_ID'] = targets['customer_ID'].str[-16:].str.hex_to_int().astype('int64')
targets.index = targets['customer_ID'].sort_index()
targets = targets.drop('customer_ID', axis=1)

print(type(train))
print(type(targets))
train = train.join(targets).sort_index()

del targets
gc.collect()

train = train.fillna(NAN_VALUE)

# FEATURES
FEATURES = train.columns[1:-1]
# Out:
# <class 'cudf.core.dataframe.DataFrame'>
# <class 'cudf.core.dataframe.DataFrame'>

# %%
target = train.target.values

# %% [markdown]
# ## Faster metric Implementation
#
# reference:https://www.kaggle.com/competitions/amex-default-prediction/discussion/328020

# %%
def amex_metric(y_true: np.array, y_pred: np.array) -> float:

    # count of positives and negatives
    n_pos = y_true.sum()
    n_neg = y_true.shape[0] - n_pos

    # sorting by descring prediction values
    indices = np.argsort(y_pred)[::-1]
    preds, target = y_pred[indices], y_true[indices]

    # filter the top 4% by cumulative row weights
    weight = 20.0 - target * 19.0
    cum_norm_weight = (weight / weight.sum()).cumsum()
    four_pct_filter = cum_norm_weight <= 0.04

    # default rate captured at 4%
    d = target[four_pct_filter].sum() / n_pos

    # weighted gini coefficient
    lorentz = (target / n_pos).cumsum()
    gini = ((lorentz - cum_norm_weight) * weight).sum()

    # max weighted gini coefficient
    gini_max = 10 * n_neg * (1 - 19 / (n_pos + 20 * n_neg))

    # normalized weighted gini coefficient
    g = gini / gini_max

    return 0.5 * (g + d)

def lgb_amex_metric(y_true, y_pred):
    return ('Score',
            amex_metric(y_true, y_pred),
            True)

# %%
import datetime
import warnings
import gc
import pickle
import lightgbm as lgb

from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier, log_evaluation, early_stopping, record_evaluation
from copy import deepcopy
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## Train LightGBM

# %%
features = [f for f in train.columns if f != 'customer_ID' and f != 'target']
print("Number of Features :",len(features))
def lgbm_params(random_state=1, n_estimators=3150):
    return LGBMClassifier(n_estimators=n_estimators,
                          #boosting_type = 'dart',
                          learning_rate=0.03, reg_lambda=50,
                          min_child_samples=2400,
                          num_leaves=100,
                          colsample_bytree=0.19,
                          device='gpu',
                          random_state=random_state, metric="None")
# Out:
# Number of Features : 1121

# %%
# create a callback function to save the best model for dart...
class _DartSaveBestModel:
    
    def __init__(self,eval_result):
        self.eval_result = eval_result
        
    def __call__(self,env):
        global best_score
        global file
        if env.iteration>1:
            eval_result_list = eval_result['valid_0']['Score']
            if eval_result_list[-1] > best_score:
                best_score = eval_result_list[-1]
                #print(f"new best score {best_score}, saving the model")
                #print(env.params)
                if env.iteration>100:
                    pickle.dump(env.model, open(file, 'wb'))

def lgb_dart_callback(eval_result):
    return _DartSaveBestModel(eval_result)

# %%
score_list = []
kf = StratifiedKFold(n_splits=5)

global file
global best_score
for fold, (train_idx, valid_idx) in enumerate(kf.split(train, train.target.to_array())):
    print('#'*25)
    print('### Fold',fold)
    print('### Train size:',len(train_idx),', Validation size:',len(valid_idx))
    print('#'*25)
    X_tr, X_val, y_tr, y_val, model = None, None, None, None, None
    start_time = datetime.datetime.now()
    X_tr = train.iloc[train_idx][features].as_gpu_matrix()
    X_val = train.iloc[valid_idx][features].as_gpu_matrix()
    y_tr = cupy.asarray(train.iloc[train_idx]["target"])
    y_val = cupy.asarray(train.iloc[valid_idx]["target"])
    
    model = lgbm_params()
    eval_result = {}
    best_score = 0
    file = f'LGBM_v{VER}_fold{fold}.pkl'
    with warnings.catch_warnings():
        warnings.filterwarnings('ignore', category=UserWarning)
        model.fit(X_tr, cupy.asnumpy(y_tr),
                  eval_set = [(X_val, cupy.asnumpy(y_val))], 
                  eval_metric=[lgb_amex_metric],
                  callbacks=[log_evaluation(10),early_stopping(1500),record_evaluation(eval_result),lgb_dart_callback(eval_result)])
    print(f"printing using current round of model..")
    pickle.dump(model, open(f'LGBM_v{VER}_fold{fold}_current.pkl', 'wb'))
    y_val_pred = model.predict_proba(X_val, raw_score=True)
    score = amex_metric(y_val, y_val_pred)
    print(f"\n\n\nFold {fold} | Training Time: {str(datetime.datetime.now() - start_time)[-12:-7]} |"
          f" Score = {score:.5f}\n\n\n")
    
    print(f"printing using best round of model..")
    with open(file, 'rb') as pickle_file:
        best_model = pickle.load(pickle_file)
    y_val_pred = best_model.predict(X_val, raw_score=True)
    score = amex_metric(y_val, y_val_pred)
    print(f"\n\n\nFold {fold} | Training Time: {str(datetime.datetime.now() - start_time)[-12:-7]} |"
          f" Score = {score:.5f}\n\n\n")
    score_list.append(score)
    
    del X_val, y_val, score, model, best_model, best_score
    gc.collect()
    
print(f"\n\n\nScore: {np.mean(cupy.asarray(score_list)):.5f}\n\n\n")
# Out:
# #########################
# ### Fold 0
# ### Train size: 367130 , Validation size: 91783
# #########################
# Training until validation scores don't improve for 1500 rounds
# [10]	valid_0's Score: 0.732998
# [20]	valid_0's Score: 0.738805
# [30]	valid_0's Score: 0.743925
# [40]	valid_0's Score: 0.749257
# [50]	valid_0's Score: 0.75129
# [60]	valid_0's Score: 0.754712
# [70]	valid_0's Score: 0.757253
# [80]	valid_0's Score: 0.759642
# [90]	valid_0's Score: 0.762676
# [100]	valid_0's Score: 0.763735
# [110]	valid_0's Score: 0.765027
# [120]	valid_0's Score: 0.767374
# [130]	valid_0's Score: 0.769009
# [140]	valid_0's Score: 0.770996
# [150]	valid_0's Score: 0.771829
# [160]	valid_0's Score: 0.773237
# [170]	valid_0's Score: 0.774366
# [180]	valid_0's Score: 0.775825
# [190]	valid_0's Score: 0.777269
# [200]	valid_0's Score: 0.777958
# [210]	valid_0's Score: 0.778559
# [220]	valid_0's Score: 0.779652
# [230]	valid_0's Score: 0.780762
# [240]	valid_0's Score: 0.781724
# [250]	valid_0's Score: 0.782763
# [260]	valid_0's Score: 0.782898
# [270]	valid_0's Score: 0.783795
# [280]	valid_0's Score: 0.784153
# [290]	valid_0's Score: 0.784349
# [300]	valid_0's Score: 0.784923
# [310]	valid_0's Score: 0.785524
# [320]	valid_0's Score: 0.785251
# [330]	valid_0's Score: 0.785663
# [340]	valid_0's Score: 0.786307
# [350]	valid_0's Score: 0.786721
# [360]	valid_0's Score: 0.786699
# [370]	valid_0's Score: 0.786832
# [380]	valid_0's Score: 0.786945
# [390]	valid_0's Score: 0.787366
# [400]	valid_0's Score: 0.787835
# [410]	valid_0's Score: 0.788595
# [420]	valid_0's Score: 0.788671
# [430]	valid_0's Score: 0.788731
# [440]	valid_0's Score: 0.788877
# [450]	valid_0's Score: 0.788726
# [460]	valid_0's Score: 0.788986
# [470]	valid_0's Score: 0.789421
# [480]	valid_0's Score: 0.78944
# [490]	valid_0's Score: 0.789922
# [500]	valid_0's Score: 0.789796
# [510]	valid_0's Score: 0.789828
# [520]	valid_0's Score: 0.790009
# [530]	valid_0's Score: 0.79004
# [540]	valid_0's Score: 0.789705
# [550]	valid_0's Score: 0.790253
# [560]	valid_0's Score: 0.790184
# [570]	valid_0's Score: 0.790457
# [580]	valid_0's Score: 0.790396
# [590]	valid_0's Score: 0.790457
# [600]	valid_0's Score: 0.790831
# [610]	valid_0's Score: 0.791042
# [620]	valid_0's Score: 0.790942
# [630]	valid_0's Score: 0.791367
# [640]	valid_0's Score: 0.791301
# [650]	valid_0's Score: 0.791278
# [660]	valid_0's Score: 0.791314
# [670]	valid_0's Score: 0.791667
# [680]	valid_0's Score: 0.791667
# [690]	valid_0's Score: 0.791803
# [700]	valid_0's Score: 0.791854
# [710]	valid_0's Score: 0.791635
# [720]	valid_0's Score: 0.791642
# [730]	valid_0's Score: 0.792078
# [740]	valid_0's Score: 0.792324
# [750]	valid_0's Score: 0.792251
# [760]	valid_0's Score: 0.792622
# [770]	valid_0's Score: 0.79274
# [780]	valid_0's Score: 0.79281
# [790]	valid_0's Score: 0.793008
# [800]	valid_0's Score: 0.792938
# [810]	valid_0's Score: 0.792911
# [820]	valid_0's Score: 0.792601
# [830]	valid_0's Score: 0.792467
# [840]	valid_0's Score: 0.792219
# [850]	valid_0's Score: 0.792636
# [860]	valid_0's Score: 0.792726
# [870]	valid_0's Score: 0.79269
# [880]	valid_0's Score: 0.792739
# [890]	valid_0's Score: 0.792531
# [900]	valid_0's Score: 0.792615
# [910]	valid_0's Score: 0.792391
# [920]	valid_0's Score: 0.792394
# [930]	valid_0's Score: 0.792189
# [940]	valid_0's Score: 0.792047
# [950]	valid_0's Score: 0.792686
# [960]	valid_0's Score: 0.792212
# [970]	valid_0's Score: 0.791883
# [980]	valid_0's Score: 0.791635
# [990]	valid_0's Score: 0.791748
# [1000]	valid_0's Score: 0.792082
# [1010]	valid_0's Score: 0.792256
# [1020]	valid_0's Score: 0.792197
# [1030]	valid_0's Score: 0.792627
# [1040]	valid_0's Score: 0.792716
# [1050]	valid_0's Score: 0.792529
# [1060]	valid_0's Score: 0.792556
# [1070]	valid_0's Score: 0.792811
# [1080]	valid_0's Score: 0.792797
# [1090]	valid_0's Score: 0.792753
# [1100]	valid_0's Score: 0.792459
# [1110]	valid_0's Score: 0.792457
# [1120]	valid_0's Score: 0.792483
# [1130]	valid_0's Score: 0.792104
# [1140]	valid_0's Score: 0.792336
# [1150]	valid_0's Score: 0.792364
# [1160]	valid_0's Score: 0.792377
# [1170]	valid_0's Score: 0.792764
# [1180]	valid_0's Score: 0.792686
# [1190]	valid_0's Score: 0.793149
# [1200]	valid_0's Score: 0.793406
# [1210]	valid_0's Score: 0.793049
# [1220]	valid_0's Score: 0.792948
# [1230]	valid_0's Score: 0.793221
# [1240]	valid_0's Score: 0.7932
# [1250]	valid_0's Score: 0.793094
# [1260]	valid_0's Score: 0.793192
# [1270]	valid_0's Score: 0.792627
# [1280]	valid_0's Score: 0.792841
# [1290]	valid_0's Score: 0.792823
# [1300]	valid_0's Score: 0.79299
# [1310]	valid_0's Score: 0.792883
# [1320]	valid_0's Score: 0.793032
# [1330]	valid_0's Score: 0.792861
# [1340]	valid_0's Score: 0.792733
# [1350]	valid_0's Score: 0.792252
# [1360]	valid_0's Score: 0.792524
# [1370]	valid_0's Score: 0.792797
# [1380]	valid_0's Score: 0.792946
# [1390]	valid_0's Score: 0.792861
# [1400]	valid_0's Score: 0.79271
# [1410]	valid_0's Score: 0.792815
# [1420]	valid_0's Score: 0.792823
# [1430]	valid_0's Score: 0.792634
# [1440]	valid_0's Score: 0.792615
# [1450]	valid_0's Score: 0.792846
# [1460]	valid_0's Score: 0.792783
# [1470]	valid_0's Score: 0.79274
# [1480]	valid_0's Score: 0.792927
# [1490]	valid_0's Score: 0.792818
# [1500]	valid_0's Score: 0.793136
# [1510]	valid_0's Score: 0.793079
# [1520]	valid_0's Score: 0.793224
# [1530]	valid_0's Score: 0.792816
# [1540]	valid_0's Score: 0.792841
# [1550]	valid_0's Score: 0.792776
# [1560]	valid_0's Score: 0.792822
# [1570]	valid_0's Score: 0.792999
# [1580]	valid_0's Score: 0.793228
# [1590]	valid_0's Score: 0.793389
# [1600]	valid_0's Score: 0.793174
# [1610]	valid_0's Score: 0.793213
# [1620]	valid_0's Score: 0.793275
# [1630]	valid_0's Score: 0.792933
# [1640]	valid_0's Score: 0.793157
# [1650]	valid_0's Score: 0.792859
# [1660]	valid_0's Score: 0.792667
# [1670]	valid_0's Score: 0.792565
# [1680]	valid_0's Score: 0.792757
# [1690]	valid_0's Score: 0.792815
# [1700]	valid_0's Score: 0.792774
# [1710]	valid_0's Score: 0.792835
# [1720]	valid_0's Score: 0.792897
# [1730]	valid_0's Score: 0.79292
# [1740]	valid_0's Score: 0.792898
# [1750]	valid_0's Score: 0.792773
# [1760]	valid_0's Score: 0.79277
# [1770]	valid_0's Score: 0.792772
# [1780]	valid_0's Score: 0.793005
# [1790]	valid_0's Score: 0.792563
# [1800]	valid_0's Score: 0.792582
# [1810]	valid_0's Score: 0.792347
# [1820]	valid_0's Score: 0.792413
# [1830]	valid_0's Score: 0.792576
# [1840]	valid_0's Score: 0.792681
# [1850]	valid_0's Score: 0.792741
# [1860]	valid_0's Score: 0.793057
# [1870]	valid_0's Score: 0.792763
# [1880]	valid_0's Score: 0.793081
# [1890]	valid_0's Score: 0.79257
# [1900]	valid_0's Score: 0.79284
# [1910]	valid_0's Score: 0.793196
# [1920]	valid_0's Score: 0.792663
# [1930]	valid_0's Score: 0.79233
# [1940]	valid_0's Score: 0.792582
# [1950]	valid_0's Score: 0.792325
# [1960]	valid_0's Score: 0.792489
# [1970]	valid_0's Score: 0.792743
# [1980]	valid_0's Score: 0.79247
# [1990]	valid_0's Score: 0.792544
# [2000]	valid_0's Score: 0.792399
# [2010]	valid_0's Score: 0.792688
# [2020]	valid_0's Score: 0.792462
# [2030]	valid_0's Score: 0.792317
# [2040]	valid_0's Score: 0.792399
# [2050]	valid_0's Score: 0.792748
# [2060]	valid_0's Score: 0.792664
# [2070]	valid_0's Score: 0.792449
# [2080]	valid_0's Score: 0.792534
# [2090]	valid_0's Score: 0.792301
# [2100]	valid_0's Score: 0.792278
# [2110]	valid_0's Score: 0.79225
# [2120]	valid_0's Score: 0.79244
# [2130]	valid_0's Score: 0.792565
# [2140]	valid_0's Score: 0.792543
# [2150]	valid_0's Score: 0.792354
# [2160]	valid_0's Score: 0.79258
# [2170]	valid_0's Score: 0.792264
# [2180]	valid_0's Score: 0.792287
# [2190]	valid_0's Score: 0.792269
# [2200]	valid_0's Score: 0.792283
# [2210]	valid_0's Score: 0.791947
# [2220]	valid_0's Score: 0.79203
# [2230]	valid_0's Score: 0.792513
# [2240]	valid_0's Score: 0.792258
# [2250]	valid_0's Score: 0.79205
# [2260]	valid_0's Score: 0.791857
# [2270]	valid_0's Score: 0.791901
# [2280]	valid_0's Score: 0.79167
# [2290]	valid_0's Score: 0.792232
# [2300]	valid_0's Score: 0.792141
# [2310]	valid_0's Score: 0.79206
# [2320]	valid_0's Score: 0.792124
# [2330]	valid_0's Score: 0.792274
# [2340]	valid_0's Score: 0.791962
# [2350]	valid_0's Score: 0.791835
# [2360]	valid_0's Score: 0.792135
# [2370]	valid_0's Score: 0.792151
# [2380]	valid_0's Score: 0.792213
# [2390]	valid_0's Score: 0.792652
# [2400]	valid_0's Score: 0.792523
# [2410]	valid_0's Score: 0.79258
# [2420]	valid_0's Score: 0.792598
# [2430]	valid_0's Score: 0.792286
# [2440]	valid_0's Score: 0.792556
# [2450]	valid_0's Score: 0.792495
# [2460]	valid_0's Score: 0.792118
# [2470]	valid_0's Score: 0.792455
# [2480]	valid_0's Score: 0.792265
# [2490]	valid_0's Score: 0.792414
# [2500]	valid_0's Score: 0.792537
# [2510]	valid_0's Score: 0.792455
# [2520]	valid_0's Score: 0.792688
# [2530]	valid_0's Score: 0.79302
# [2540]	valid_0's Score: 0.793041
# [2550]	valid_0's Score: 0.793166
# [2560]	valid_0's Score: 0.792685
# [2570]	valid_0's Score: 0.79306
# [2580]	valid_0's Score: 0.792891
# [2590]	valid_0's Score: 0.792891
# [2600]	valid_0's Score: 0.792785
# [2610]	valid_0's Score: 0.793181
# [2620]	valid_0's Score: 0.792946
# [2630]	valid_0's Score: 0.793134
# [2640]	valid_0's Score: 0.792824
# [2650]	valid_0's Score: 0.79295
# [2660]	valid_0's Score: 0.792924
# [2670]	valid_0's Score: 0.792756
# [2680]	valid_0's Score: 0.792794
# [2690]	valid_0's Score: 0.792942
# [2700]	valid_0's Score: 0.79286
# [2710]	valid_0's Score: 0.792791
# [2720]	valid_0's Score: 0.792916
# [2730]	valid_0's Score: 0.792873
# [2740]	valid_0's Score: 0.793037
# [2750]	valid_0's Score: 0.792947
# [2760]	valid_0's Score: 0.792992
# [2770]	valid_0's Score: 0.793007
# [2780]	valid_0's Score: 0.793111
# [2790]	valid_0's Score: 0.793279
# [2800]	valid_0's Score: 0.793178
# [2810]	valid_0's Score: 0.793322
# [2820]	valid_0's Score: 0.793358
# [2830]	valid_0's Score: 0.793187
# [2840]	valid_0's Score: 0.792975
# [2850]	valid_0's Score: 0.792932
# [2860]	valid_0's Score: 0.792825
# [2870]	valid_0's Score: 0.792947
# [2880]	valid_0's Score: 0.79288
# [2890]	valid_0's Score: 0.792945
# [2900]	valid_0's Score: 0.79282
# [2910]	valid_0's Score: 0.793052
# [2920]	valid_0's Score: 0.792946
# [2930]	valid_0's Score: 0.79305
# [2940]	valid_0's Score: 0.792964
# [2950]	valid_0's Score: 0.793129
# [2960]	valid_0's Score: 0.792939
# [2970]	valid_0's Score: 0.792856
# [2980]	valid_0's Score: 0.792684
# [2990]	valid_0's Score: 0.792998
# [3000]	valid_0's Score: 0.793082
# [3010]	valid_0's Score: 0.792997
# [3020]	valid_0's Score: 0.793121
# [3030]	valid_0's Score: 0.793013
# [3040]	valid_0's Score: 0.792973
# [3050]	valid_0's Score: 0.793185
# [3060]	valid_0's Score: 0.793331
# [3070]	valid_0's Score: 0.793417
# [3080]	valid_0's Score: 0.793163
# [3090]	valid_0's Score: 0.793453
# [3100]	valid_0's Score: 0.79307
# [3110]	valid_0's Score: 0.793111
# Early stopping, best iteration is:
# [1614]	valid_0's Score: 0.793572
# printing using current round of model..
#
#
#
# Fold 0 | Training Time: 17:09 | Score = 0.79333
#
#
#
# printing using best round of model..
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:859: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
# Fold 0 | Training Time: 17:33 | Score = 0.79312
#
#
#
# #########################
# ### Fold 1
# ### Train size: 367130 , Validation size: 91783
# #########################
# Training until validation scores don't improve for 1500 rounds
# [10]	valid_0's Score: 0.733643
# [20]	valid_0's Score: 0.74135
# [30]	valid_0's Score: 0.746821
# [40]	valid_0's Score: 0.750339
# [50]	valid_0's Score: 0.753171
# [60]	valid_0's Score: 0.756904
# [70]	valid_0's Score: 0.759017
# [80]	valid_0's Score: 0.761503
# [90]	valid_0's Score: 0.763463
# [100]	valid_0's Score: 0.764671
# [110]	valid_0's Score: 0.766026
# [120]	valid_0's Score: 0.767856
# [130]	valid_0's Score: 0.769998
# [140]	valid_0's Score: 0.77183
# [150]	valid_0's Score: 0.773197
# [160]	valid_0's Score: 0.774499
# [170]	valid_0's Score: 0.775893
# [180]	valid_0's Score: 0.777283
# [190]	valid_0's Score: 0.777784
# [200]	valid_0's Score: 0.778512
# [210]	valid_0's Score: 0.778686
# [220]	valid_0's Score: 0.779456
# [230]	valid_0's Score: 0.780224
# [240]	valid_0's Score: 0.781188
# [250]	valid_0's Score: 0.781351
# [260]	valid_0's Score: 0.782105
# [270]	valid_0's Score: 0.782594
# [280]	valid_0's Score: 0.783486
# [290]	valid_0's Score: 0.783322
# [300]	valid_0's Score: 0.783734
# [310]	valid_0's Score: 0.784609
# [320]	valid_0's Score: 0.784612
# [330]	valid_0's Score: 0.785283
# [340]	valid_0's Score: 0.785614
# [350]	valid_0's Score: 0.786022
# [360]	valid_0's Score: 0.786024
# [370]	valid_0's Score: 0.786134
# [380]	valid_0's Score: 0.786569
# [390]	valid_0's Score: 0.786665
# [400]	valid_0's Score: 0.786885
# [410]	valid_0's Score: 0.787597
# [420]	valid_0's Score: 0.787753
# [430]	valid_0's Score: 0.787683
# [440]	valid_0's Score: 0.787617
# [450]	valid_0's Score: 0.788093
# [460]	valid_0's Score: 0.788216
# [470]	valid_0's Score: 0.788666
# [480]	valid_0's Score: 0.788595
# [490]	valid_0's Score: 0.788551
# [500]	valid_0's Score: 0.789195
# [510]	valid_0's Score: 0.78971
# [520]	valid_0's Score: 0.789991
# [530]	valid_0's Score: 0.790136
# [540]	valid_0's Score: 0.790185
# [550]	valid_0's Score: 0.790414
# [560]	valid_0's Score: 0.790511
# [570]	valid_0's Score: 0.790619
# [580]	valid_0's Score: 0.790675
# [590]	valid_0's Score: 0.790715
# [600]	valid_0's Score: 0.791206
# [610]	valid_0's Score: 0.791156
# [620]	valid_0's Score: 0.790719
# [630]	valid_0's Score: 0.790902
# [640]	valid_0's Score: 0.790703
# [650]	valid_0's Score: 0.790516
# [660]	valid_0's Score: 0.790391
# [670]	valid_0's Score: 0.790676
# [680]	valid_0's Score: 0.790674
# [690]	valid_0's Score: 0.790633
# [700]	valid_0's Score: 0.790599
# [710]	valid_0's Score: 0.790713
# [720]	valid_0's Score: 0.790822
# [730]	valid_0's Score: 0.791108
# [740]	valid_0's Score: 0.791073
# [750]	valid_0's Score: 0.79106
# [760]	valid_0's Score: 0.790694
# [770]	valid_0's Score: 0.791205
# [780]	valid_0's Score: 0.790915
# [790]	valid_0's Score: 0.791045
# [800]	valid_0's Score: 0.791076
# [810]	valid_0's Score: 0.790967
# [820]	valid_0's Score: 0.790743
# [830]	valid_0's Score: 0.790765
# [840]	valid_0's Score: 0.790857
# [850]	valid_0's Score: 0.790622
# [860]	valid_0's Score: 0.79056
# [870]	valid_0's Score: 0.790673
# [880]	valid_0's Score: 0.791227
# [890]	valid_0's Score: 0.790853
# [900]	valid_0's Score: 0.7914
# [910]	valid_0's Score: 0.791005
# [920]	valid_0's Score: 0.790906
# [930]	valid_0's Score: 0.790909
# [940]	valid_0's Score: 0.791022
# [950]	valid_0's Score: 0.791193
# [960]	valid_0's Score: 0.790971
# [970]	valid_0's Score: 0.790832
# [980]	valid_0's Score: 0.791242
# [990]	valid_0's Score: 0.791175
# [1000]	valid_0's Score: 0.790901
# [1010]	valid_0's Score: 0.79124
# [1020]	valid_0's Score: 0.791268
# [1030]	valid_0's Score: 0.791186
# [1040]	valid_0's Score: 0.790911
# [1050]	valid_0's Score: 0.790929
# [1060]	valid_0's Score: 0.790785
# [1070]	valid_0's Score: 0.791103
# [1080]	valid_0's Score: 0.791283
# [1090]	valid_0's Score: 0.791156
# [1100]	valid_0's Score: 0.791042
# [1110]	valid_0's Score: 0.791131
# [1120]	valid_0's Score: 0.791678
# [1130]	valid_0's Score: 0.791239
# [1140]	valid_0's Score: 0.791521
# [1150]	valid_0's Score: 0.79171
# [1160]	valid_0's Score: 0.791652
# [1170]	valid_0's Score: 0.791734
# [1180]	valid_0's Score: 0.791878
# [1190]	valid_0's Score: 0.791797
# [1200]	valid_0's Score: 0.791567
# [1210]	valid_0's Score: 0.791572
# [1220]	valid_0's Score: 0.791639
# [1230]	valid_0's Score: 0.791936
# [1240]	valid_0's Score: 0.791748
# [1250]	valid_0's Score: 0.791854
# [1260]	valid_0's Score: 0.791683
# [1270]	valid_0's Score: 0.791828
# [1280]	valid_0's Score: 0.792121
# [1290]	valid_0's Score: 0.791752
# [1300]	valid_0's Score: 0.791747
# [1310]	valid_0's Score: 0.791892
# [1320]	valid_0's Score: 0.79212
# [1330]	valid_0's Score: 0.792073
# [1340]	valid_0's Score: 0.791941
# [1350]	valid_0's Score: 0.791946
# [1360]	valid_0's Score: 0.79207
# [1370]	valid_0's Score: 0.792373
# [1380]	valid_0's Score: 0.792056
# [1390]	valid_0's Score: 0.79216
# [1400]	valid_0's Score: 0.791953
# [1410]	valid_0's Score: 0.7921
# [1420]	valid_0's Score: 0.79176
# [1430]	valid_0's Score: 0.791252
# [1440]	valid_0's Score: 0.791317
# [1450]	valid_0's Score: 0.791277
# [1460]	valid_0's Score: 0.79153
# [1470]	valid_0's Score: 0.791297
# [1480]	valid_0's Score: 0.790937
# [1490]	valid_0's Score: 0.791628
# [1500]	valid_0's Score: 0.791732
# [1510]	valid_0's Score: 0.791309
# [1520]	valid_0's Score: 0.791521
# [1530]	valid_0's Score: 0.791284
# [1540]	valid_0's Score: 0.791393
# [1550]	valid_0's Score: 0.791474
# [1560]	valid_0's Score: 0.791304
# [1570]	valid_0's Score: 0.791092
# [1580]	valid_0's Score: 0.790896
# [1590]	valid_0's Score: 0.791002
# [1600]	valid_0's Score: 0.790624
# [1610]	valid_0's Score: 0.790677
# [1620]	valid_0's Score: 0.790908
# [1630]	valid_0's Score: 0.790505
# [1640]	valid_0's Score: 0.790542
# [1650]	valid_0's Score: 0.790836
# [1660]	valid_0's Score: 0.79104
# [1670]	valid_0's Score: 0.791103
# [1680]	valid_0's Score: 0.791057
# [1690]	valid_0's Score: 0.791074
# [1700]	valid_0's Score: 0.790975
# [1710]	valid_0's Score: 0.790972
# [1720]	valid_0's Score: 0.790274
# [1730]	valid_0's Score: 0.79031
# [1740]	valid_0's Score: 0.790206
# [1750]	valid_0's Score: 0.790398
# [1760]	valid_0's Score: 0.790567
# [1770]	valid_0's Score: 0.790627
# [1780]	valid_0's Score: 0.790732
# [1790]	valid_0's Score: 0.790621
# [1800]	valid_0's Score: 0.790453
# [1810]	valid_0's Score: 0.790472
# [1820]	valid_0's Score: 0.790699
# [1830]	valid_0's Score: 0.790888
# [1840]	valid_0's Score: 0.790761
# [1850]	valid_0's Score: 0.790759
# [1860]	valid_0's Score: 0.790695
# [1870]	valid_0's Score: 0.790397
# [1880]	valid_0's Score: 0.790755
# [1890]	valid_0's Score: 0.790625
# [1900]	valid_0's Score: 0.790608
# [1910]	valid_0's Score: 0.790623
# [1920]	valid_0's Score: 0.790983
# [1930]	valid_0's Score: 0.790914
# [1940]	valid_0's Score: 0.790766
# [1950]	valid_0's Score: 0.791015
# [1960]	valid_0's Score: 0.790802
# [1970]	valid_0's Score: 0.790569
# [1980]	valid_0's Score: 0.790937
# [1990]	valid_0's Score: 0.791002
# [2000]	valid_0's Score: 0.790999
# [2010]	valid_0's Score: 0.790952
# [2020]	valid_0's Score: 0.791163
# [2030]	valid_0's Score: 0.791142
# [2040]	valid_0's Score: 0.791328
# [2050]	valid_0's Score: 0.791238
# [2060]	valid_0's Score: 0.791156
# [2070]	valid_0's Score: 0.791007
# [2080]	valid_0's Score: 0.791064
# [2090]	valid_0's Score: 0.790993
# [2100]	valid_0's Score: 0.790946
# [2110]	valid_0's Score: 0.790946
# [2120]	valid_0's Score: 0.790945
# [2130]	valid_0's Score: 0.790964
# [2140]	valid_0's Score: 0.79058
# [2150]	valid_0's Score: 0.790451
# [2160]	valid_0's Score: 0.791018
# [2170]	valid_0's Score: 0.790996
# [2180]	valid_0's Score: 0.791056
# [2190]	valid_0's Score: 0.790933
# [2200]	valid_0's Score: 0.790745
# [2210]	valid_0's Score: 0.790912
# [2220]	valid_0's Score: 0.790718
# [2230]	valid_0's Score: 0.790971
# [2240]	valid_0's Score: 0.791006
# [2250]	valid_0's Score: 0.790942
# [2260]	valid_0's Score: 0.791126
# [2270]	valid_0's Score: 0.79096
# [2280]	valid_0's Score: 0.790963
# [2290]	valid_0's Score: 0.791108
# [2300]	valid_0's Score: 0.791091
# [2310]	valid_0's Score: 0.790748
# [2320]	valid_0's Score: 0.791169
# [2330]	valid_0's Score: 0.791168
# [2340]	valid_0's Score: 0.791418
# [2350]	valid_0's Score: 0.791349
# [2360]	valid_0's Score: 0.791286
# [2370]	valid_0's Score: 0.791034
# [2380]	valid_0's Score: 0.791308
# [2390]	valid_0's Score: 0.79097
# [2400]	valid_0's Score: 0.791112
# [2410]	valid_0's Score: 0.791133
# [2420]	valid_0's Score: 0.790918
# [2430]	valid_0's Score: 0.790768
# [2440]	valid_0's Score: 0.79104
# [2450]	valid_0's Score: 0.790933
# [2460]	valid_0's Score: 0.79082
# [2470]	valid_0's Score: 0.790669
# [2480]	valid_0's Score: 0.790748
# [2490]	valid_0's Score: 0.790764
# [2500]	valid_0's Score: 0.790699
# [2510]	valid_0's Score: 0.790505
# [2520]	valid_0's Score: 0.790502
# [2530]	valid_0's Score: 0.790587
# [2540]	valid_0's Score: 0.790494
# [2550]	valid_0's Score: 0.790257
# [2560]	valid_0's Score: 0.790278
# [2570]	valid_0's Score: 0.790002
# [2580]	valid_0's Score: 0.790799
# [2590]	valid_0's Score: 0.790667
# [2600]	valid_0's Score: 0.79079
# [2610]	valid_0's Score: 0.790663
# [2620]	valid_0's Score: 0.790724
# [2630]	valid_0's Score: 0.790618
# [2640]	valid_0's Score: 0.79015
# [2650]	valid_0's Score: 0.789787
# [2660]	valid_0's Score: 0.789849
# [2670]	valid_0's Score: 0.789822
# [2680]	valid_0's Score: 0.789987
# [2690]	valid_0's Score: 0.79005
# [2700]	valid_0's Score: 0.790532
# [2710]	valid_0's Score: 0.790408
# [2720]	valid_0's Score: 0.790494
# [2730]	valid_0's Score: 0.790411
# [2740]	valid_0's Score: 0.790368
# [2750]	valid_0's Score: 0.790407
# [2760]	valid_0's Score: 0.790477
# [2770]	valid_0's Score: 0.790433
# [2780]	valid_0's Score: 0.790054
# [2790]	valid_0's Score: 0.790198
# [2800]	valid_0's Score: 0.790487
# [2810]	valid_0's Score: 0.790402
# [2820]	valid_0's Score: 0.790292
# [2830]	valid_0's Score: 0.790481
# [2840]	valid_0's Score: 0.790546
# [2850]	valid_0's Score: 0.790565
# [2860]	valid_0's Score: 0.790938
# Early stopping, best iteration is:
# [1368]	valid_0's Score: 0.792518
# printing using current round of model..
#
#
#
# Fold 1 | Training Time: 15:57 | Score = 0.79228
#
#
#
# printing using best round of model..
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:859: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
# Fold 1 | Training Time: 16:20 | Score = 0.79199
#
#
#
# #########################
# ### Fold 2
# ### Train size: 367130 , Validation size: 91783
# #########################
# Training until validation scores don't improve for 1500 rounds
# [10]	valid_0's Score: 0.740334
# [20]	valid_0's Score: 0.744798
# [30]	valid_0's Score: 0.749217
# [40]	valid_0's Score: 0.75308
# [50]	valid_0's Score: 0.756572
# [60]	valid_0's Score: 0.759468
# [70]	valid_0's Score: 0.762167
# [80]	valid_0's Score: 0.765061
# [90]	valid_0's Score: 0.766934
# [100]	valid_0's Score: 0.768995
# [110]	valid_0's Score: 0.770544
# [120]	valid_0's Score: 0.772296
# [130]	valid_0's Score: 0.774195
# [140]	valid_0's Score: 0.775727
# [150]	valid_0's Score: 0.776959
# [160]	valid_0's Score: 0.777976
# [170]	valid_0's Score: 0.779473
# [180]	valid_0's Score: 0.779866
# [190]	valid_0's Score: 0.780699
# [200]	valid_0's Score: 0.781364
# [210]	valid_0's Score: 0.782672
# [220]	valid_0's Score: 0.783818
# [230]	valid_0's Score: 0.785069
# [240]	valid_0's Score: 0.785476
# [250]	valid_0's Score: 0.785798
# [260]	valid_0's Score: 0.785801
# [270]	valid_0's Score: 0.786372
# [280]	valid_0's Score: 0.786514
# [290]	valid_0's Score: 0.787096
# [300]	valid_0's Score: 0.786954
# [310]	valid_0's Score: 0.787517
# [320]	valid_0's Score: 0.787599
# [330]	valid_0's Score: 0.787611
# [340]	valid_0's Score: 0.788276
# [350]	valid_0's Score: 0.788217
# [360]	valid_0's Score: 0.788601
# [370]	valid_0's Score: 0.789118
# [380]	valid_0's Score: 0.789429
# [390]	valid_0's Score: 0.789295
# [400]	valid_0's Score: 0.789391
# [410]	valid_0's Score: 0.79019
# [420]	valid_0's Score: 0.790212
# [430]	valid_0's Score: 0.790514
# [440]	valid_0's Score: 0.790434
# [450]	valid_0's Score: 0.790887
# [460]	valid_0's Score: 0.790499
# [470]	valid_0's Score: 0.790466
# [480]	valid_0's Score: 0.791048
# [490]	valid_0's Score: 0.790853
# [500]	valid_0's Score: 0.790955
# [510]	valid_0's Score: 0.790707
# [520]	valid_0's Score: 0.790704
# [530]	valid_0's Score: 0.791165
# [540]	valid_0's Score: 0.791609
# [550]	valid_0's Score: 0.791508
# [560]	valid_0's Score: 0.791845
# [570]	valid_0's Score: 0.791545
# [580]	valid_0's Score: 0.791984
# [590]	valid_0's Score: 0.791748
# [600]	valid_0's Score: 0.792273
# [610]	valid_0's Score: 0.792419
# [620]	valid_0's Score: 0.792488
# [630]	valid_0's Score: 0.792524
# [640]	valid_0's Score: 0.79231
# [650]	valid_0's Score: 0.792237
# [660]	valid_0's Score: 0.792233
# [670]	valid_0's Score: 0.792567
# [680]	valid_0's Score: 0.792582
# [690]	valid_0's Score: 0.793205
# [700]	valid_0's Score: 0.793189
# [710]	valid_0's Score: 0.793053
# [720]	valid_0's Score: 0.793141
# [730]	valid_0's Score: 0.793267
# [740]	valid_0's Score: 0.793065
# [750]	valid_0's Score: 0.793233
# [760]	valid_0's Score: 0.793327
# [770]	valid_0's Score: 0.79359
# [780]	valid_0's Score: 0.793925
# [790]	valid_0's Score: 0.793469
# [800]	valid_0's Score: 0.793733
# [810]	valid_0's Score: 0.794029
# [820]	valid_0's Score: 0.793979
# [830]	valid_0's Score: 0.793803
# [840]	valid_0's Score: 0.793709
# [850]	valid_0's Score: 0.793652
# [860]	valid_0's Score: 0.793634
# [870]	valid_0's Score: 0.793748
# [880]	valid_0's Score: 0.793817
# [890]	valid_0's Score: 0.793923
# [900]	valid_0's Score: 0.794035
# [910]	valid_0's Score: 0.794077
# [920]	valid_0's Score: 0.793933
# [930]	valid_0's Score: 0.79399
# [940]	valid_0's Score: 0.794067
# [950]	valid_0's Score: 0.793881
# [960]	valid_0's Score: 0.793912
# [970]	valid_0's Score: 0.794229
# [980]	valid_0's Score: 0.793592
# [990]	valid_0's Score: 0.793897
# [1000]	valid_0's Score: 0.794135
# [1010]	valid_0's Score: 0.79431
# [1020]	valid_0's Score: 0.794604
# [1030]	valid_0's Score: 0.794528
# [1040]	valid_0's Score: 0.794365
# [1050]	valid_0's Score: 0.794261
# [1060]	valid_0's Score: 0.794329
# [1070]	valid_0's Score: 0.794393
# [1080]	valid_0's Score: 0.794546
# [1090]	valid_0's Score: 0.794735
# [1100]	valid_0's Score: 0.794644
# [1110]	valid_0's Score: 0.794118
# [1120]	valid_0's Score: 0.794141
# [1130]	valid_0's Score: 0.79427
# [1140]	valid_0's Score: 0.794154
# [1150]	valid_0's Score: 0.793967
# [1160]	valid_0's Score: 0.79384
# [1170]	valid_0's Score: 0.794024
# [1180]	valid_0's Score: 0.794177
# [1190]	valid_0's Score: 0.794138
# [1200]	valid_0's Score: 0.7941
# [1210]	valid_0's Score: 0.794245
# [1220]	valid_0's Score: 0.794225
# [1230]	valid_0's Score: 0.794172
# [1240]	valid_0's Score: 0.794533
# [1250]	valid_0's Score: 0.794574
# [1260]	valid_0's Score: 0.793906
# [1270]	valid_0's Score: 0.794264
# [1280]	valid_0's Score: 0.794263
# [1290]	valid_0's Score: 0.794224
# [1300]	valid_0's Score: 0.794207
# [1310]	valid_0's Score: 0.794159
# [1320]	valid_0's Score: 0.794262
# [1330]	valid_0's Score: 0.79434
# [1340]	valid_0's Score: 0.79413
# [1350]	valid_0's Score: 0.793818
# [1360]	valid_0's Score: 0.794096
# [1370]	valid_0's Score: 0.794243
# [1380]	valid_0's Score: 0.794373
# [1390]	valid_0's Score: 0.794158
# [1400]	valid_0's Score: 0.794118
# [1410]	valid_0's Score: 0.793973
# [1420]	valid_0's Score: 0.793805
# [1430]	valid_0's Score: 0.794083
# [1440]	valid_0's Score: 0.794147
# [1450]	valid_0's Score: 0.794337
# [1460]	valid_0's Score: 0.793894
# [1470]	valid_0's Score: 0.794185
# [1480]	valid_0's Score: 0.794071
# [1490]	valid_0's Score: 0.794134
# [1500]	valid_0's Score: 0.794283
# [1510]	valid_0's Score: 0.794448
# [1520]	valid_0's Score: 0.794216
# [1530]	valid_0's Score: 0.794575
# [1540]	valid_0's Score: 0.794601
# [1550]	valid_0's Score: 0.794557
# [1560]	valid_0's Score: 0.794427
# [1570]	valid_0's Score: 0.794619
# [1580]	valid_0's Score: 0.794473
# [1590]	valid_0's Score: 0.794239
# [1600]	valid_0's Score: 0.794138
# [1610]	valid_0's Score: 0.793754
# [1620]	valid_0's Score: 0.793981
# [1630]	valid_0's Score: 0.794066
# [1640]	valid_0's Score: 0.794101
# [1650]	valid_0's Score: 0.794191
# [1660]	valid_0's Score: 0.794188
# [1670]	valid_0's Score: 0.794635
# [1680]	valid_0's Score: 0.794213
# [1690]	valid_0's Score: 0.794299
# [1700]	valid_0's Score: 0.794262
# [1710]	valid_0's Score: 0.794158
# [1720]	valid_0's Score: 0.794075
# [1730]	valid_0's Score: 0.794116
# [1740]	valid_0's Score: 0.793625
# [1750]	valid_0's Score: 0.79364
# [1760]	valid_0's Score: 0.793612
# [1770]	valid_0's Score: 0.793715
# [1780]	valid_0's Score: 0.793687
# [1790]	valid_0's Score: 0.793493
# [1800]	valid_0's Score: 0.793701
# [1810]	valid_0's Score: 0.793278
# [1820]	valid_0's Score: 0.793662
# [1830]	valid_0's Score: 0.793705
# [1840]	valid_0's Score: 0.793634
# [1850]	valid_0's Score: 0.793988
# [1860]	valid_0's Score: 0.794038
# [1870]	valid_0's Score: 0.793683
# [1880]	valid_0's Score: 0.793641
# [1890]	valid_0's Score: 0.793773
# [1900]	valid_0's Score: 0.793602
# [1910]	valid_0's Score: 0.793334
# [1920]	valid_0's Score: 0.793571
# [1930]	valid_0's Score: 0.793384
# [1940]	valid_0's Score: 0.793552
# [1950]	valid_0's Score: 0.793423
# [1960]	valid_0's Score: 0.79371
# [1970]	valid_0's Score: 0.793541
# [1980]	valid_0's Score: 0.793287
# [1990]	valid_0's Score: 0.793708
# [2000]	valid_0's Score: 0.793849
# [2010]	valid_0's Score: 0.793531
# [2020]	valid_0's Score: 0.793848
# [2030]	valid_0's Score: 0.793699
# [2040]	valid_0's Score: 0.793697
# [2050]	valid_0's Score: 0.793969
# [2060]	valid_0's Score: 0.794118
# [2070]	valid_0's Score: 0.793967
# [2080]	valid_0's Score: 0.793926
# [2090]	valid_0's Score: 0.794133
# [2100]	valid_0's Score: 0.794244
# [2110]	valid_0's Score: 0.794179
# [2120]	valid_0's Score: 0.794221
# [2130]	valid_0's Score: 0.794116
# [2140]	valid_0's Score: 0.794474
# [2150]	valid_0's Score: 0.794348
# [2160]	valid_0's Score: 0.794368
# [2170]	valid_0's Score: 0.794281
# [2180]	valid_0's Score: 0.794552
# [2190]	valid_0's Score: 0.79436
# [2200]	valid_0's Score: 0.794149
# [2210]	valid_0's Score: 0.7941
# [2220]	valid_0's Score: 0.793929
# [2230]	valid_0's Score: 0.793992
# [2240]	valid_0's Score: 0.7937
# [2250]	valid_0's Score: 0.793693
# [2260]	valid_0's Score: 0.793692
# [2270]	valid_0's Score: 0.794095
# [2280]	valid_0's Score: 0.793837
# [2290]	valid_0's Score: 0.793714
# [2300]	valid_0's Score: 0.793817
# [2310]	valid_0's Score: 0.794108
# [2320]	valid_0's Score: 0.793819
# [2330]	valid_0's Score: 0.793751
# [2340]	valid_0's Score: 0.793667
# [2350]	valid_0's Score: 0.793751
# [2360]	valid_0's Score: 0.793792
# [2370]	valid_0's Score: 0.793429
# [2380]	valid_0's Score: 0.793682
# [2390]	valid_0's Score: 0.793551
# [2400]	valid_0's Score: 0.793655
# [2410]	valid_0's Score: 0.793905
# [2420]	valid_0's Score: 0.794074
# [2430]	valid_0's Score: 0.793721
# [2440]	valid_0's Score: 0.793695
# [2450]	valid_0's Score: 0.793739
# [2460]	valid_0's Score: 0.793711
# [2470]	valid_0's Score: 0.793793
# [2480]	valid_0's Score: 0.79396
# [2490]	valid_0's Score: 0.793636
# [2500]	valid_0's Score: 0.793484
# [2510]	valid_0's Score: 0.793419
# [2520]	valid_0's Score: 0.793708
# [2530]	valid_0's Score: 0.793643
# [2540]	valid_0's Score: 0.793625
# [2550]	valid_0's Score: 0.793414
# [2560]	valid_0's Score: 0.793306
# [2570]	valid_0's Score: 0.793428
# [2580]	valid_0's Score: 0.793482
# [2590]	valid_0's Score: 0.793169
# [2600]	valid_0's Score: 0.793339
# [2610]	valid_0's Score: 0.793318
# [2620]	valid_0's Score: 0.793446
# [2630]	valid_0's Score: 0.793651
# [2640]	valid_0's Score: 0.793084
# [2650]	valid_0's Score: 0.792704
# [2660]	valid_0's Score: 0.792823
# [2670]	valid_0's Score: 0.792796
# [2680]	valid_0's Score: 0.793086
# [2690]	valid_0's Score: 0.793084
# [2700]	valid_0's Score: 0.793083
# [2710]	valid_0's Score: 0.793122
# [2720]	valid_0's Score: 0.79312
# [2730]	valid_0's Score: 0.793059
# [2740]	valid_0's Score: 0.793206
# [2750]	valid_0's Score: 0.792996
# Early stopping, best iteration is:
# [1251]	valid_0's Score: 0.794954
# printing using current round of model..
#
#
#
# Fold 2 | Training Time: 15:43 | Score = 0.79472
#
#
#
# printing using best round of model..
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:859: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
# Fold 2 | Training Time: 16:03 | Score = 0.79444
#
#
#
# #########################
# ### Fold 3
# ### Train size: 367131 , Validation size: 91782
# #########################
# Training until validation scores don't improve for 1500 rounds
# [10]	valid_0's Score: 0.734549
# [20]	valid_0's Score: 0.741173
# [30]	valid_0's Score: 0.747247
# [40]	valid_0's Score: 0.750143
# [50]	valid_0's Score: 0.752899
# [60]	valid_0's Score: 0.756513
# [70]	valid_0's Score: 0.758432
# [80]	valid_0's Score: 0.760943
# [90]	valid_0's Score: 0.762844
# [100]	valid_0's Score: 0.76491
# [110]	valid_0's Score: 0.766319
# [120]	valid_0's Score: 0.768797
# [130]	valid_0's Score: 0.771216
# [140]	valid_0's Score: 0.771807
# [150]	valid_0's Score: 0.773324
# [160]	valid_0's Score: 0.77488
# [170]	valid_0's Score: 0.776819
# [180]	valid_0's Score: 0.778248
# [190]	valid_0's Score: 0.779208
# [200]	valid_0's Score: 0.779699
# [210]	valid_0's Score: 0.780087
# [220]	valid_0's Score: 0.780448
# [230]	valid_0's Score: 0.780906
# [240]	valid_0's Score: 0.781393
# [250]	valid_0's Score: 0.782744
# [260]	valid_0's Score: 0.784087
# [270]	valid_0's Score: 0.784438
# [280]	valid_0's Score: 0.784652
# [290]	valid_0's Score: 0.785148
# [300]	valid_0's Score: 0.785728
# [310]	valid_0's Score: 0.78567
# [320]	valid_0's Score: 0.786315
# [330]	valid_0's Score: 0.786727
# [340]	valid_0's Score: 0.786959
# [350]	valid_0's Score: 0.787658
# [360]	valid_0's Score: 0.787817
# [370]	valid_0's Score: 0.788252
# [380]	valid_0's Score: 0.788596
# [390]	valid_0's Score: 0.788624
# [400]	valid_0's Score: 0.788589
# [410]	valid_0's Score: 0.788888
# [420]	valid_0's Score: 0.789189
# [430]	valid_0's Score: 0.789464
# [440]	valid_0's Score: 0.789817
# [450]	valid_0's Score: 0.790008
# [460]	valid_0's Score: 0.790045
# [470]	valid_0's Score: 0.790435
# [480]	valid_0's Score: 0.790532
# [490]	valid_0's Score: 0.790978
# [500]	valid_0's Score: 0.790948
# [510]	valid_0's Score: 0.790997
# [520]	valid_0's Score: 0.791115
# [530]	valid_0's Score: 0.791504
# [540]	valid_0's Score: 0.791294
# [550]	valid_0's Score: 0.791656
# [560]	valid_0's Score: 0.791616
# [570]	valid_0's Score: 0.791731
# [580]	valid_0's Score: 0.791416
# [590]	valid_0's Score: 0.791774
# [600]	valid_0's Score: 0.792274
# [610]	valid_0's Score: 0.792303
# [620]	valid_0's Score: 0.792331
# [630]	valid_0's Score: 0.792369
# [640]	valid_0's Score: 0.792692
# [650]	valid_0's Score: 0.792785
# [660]	valid_0's Score: 0.792337
# [670]	valid_0's Score: 0.792416
# [680]	valid_0's Score: 0.792557
# [690]	valid_0's Score: 0.792464
# [700]	valid_0's Score: 0.792858
# [710]	valid_0's Score: 0.792452
# [720]	valid_0's Score: 0.792471
# [730]	valid_0's Score: 0.792854
# [740]	valid_0's Score: 0.792598
# [750]	valid_0's Score: 0.792924
# [760]	valid_0's Score: 0.792715
# [770]	valid_0's Score: 0.792847
# [780]	valid_0's Score: 0.792818
# [790]	valid_0's Score: 0.792992
# [800]	valid_0's Score: 0.793098
# [810]	valid_0's Score: 0.792962
# [820]	valid_0's Score: 0.792926
# [830]	valid_0's Score: 0.792686
# [840]	valid_0's Score: 0.792896
# [850]	valid_0's Score: 0.79299
# [860]	valid_0's Score: 0.792877
# [870]	valid_0's Score: 0.792866
# [880]	valid_0's Score: 0.7929
# [890]	valid_0's Score: 0.79303
# [900]	valid_0's Score: 0.792902
# [910]	valid_0's Score: 0.792848
# [920]	valid_0's Score: 0.792807
# [930]	valid_0's Score: 0.792783
# [940]	valid_0's Score: 0.792496
# [950]	valid_0's Score: 0.792643
# [960]	valid_0's Score: 0.79254
# [970]	valid_0's Score: 0.792442
# [980]	valid_0's Score: 0.792016
# [990]	valid_0's Score: 0.79221
# [1000]	valid_0's Score: 0.792321
# [1010]	valid_0's Score: 0.792724
# [1020]	valid_0's Score: 0.792693
# [1030]	valid_0's Score: 0.792616
# [1040]	valid_0's Score: 0.792328
# [1050]	valid_0's Score: 0.792382
# [1060]	valid_0's Score: 0.792483
# [1070]	valid_0's Score: 0.792647
# [1080]	valid_0's Score: 0.792827
# [1090]	valid_0's Score: 0.792664
# [1100]	valid_0's Score: 0.792433
# [1110]	valid_0's Score: 0.792674
# [1120]	valid_0's Score: 0.792762
# [1130]	valid_0's Score: 0.792766
# [1140]	valid_0's Score: 0.792893
# [1150]	valid_0's Score: 0.793063
# [1160]	valid_0's Score: 0.792729
# [1170]	valid_0's Score: 0.792685
# [1180]	valid_0's Score: 0.792471
# [1190]	valid_0's Score: 0.792154
# [1200]	valid_0's Score: 0.792116
# [1210]	valid_0's Score: 0.792332
# [1220]	valid_0's Score: 0.792025
# [1230]	valid_0's Score: 0.792165
# [1240]	valid_0's Score: 0.792312
# [1250]	valid_0's Score: 0.792334
# [1260]	valid_0's Score: 0.792384
# [1270]	valid_0's Score: 0.792082
# [1280]	valid_0's Score: 0.792111
# [1290]	valid_0's Score: 0.791903
# [1300]	valid_0's Score: 0.792089
# [1310]	valid_0's Score: 0.792009
# [1320]	valid_0's Score: 0.791779
# [1330]	valid_0's Score: 0.791533
# [1340]	valid_0's Score: 0.791758
# [1350]	valid_0's Score: 0.791757
# [1360]	valid_0's Score: 0.791733
# [1370]	valid_0's Score: 0.791903
# [1380]	valid_0's Score: 0.791758
# [1390]	valid_0's Score: 0.791953
# [1400]	valid_0's Score: 0.791474
# [1410]	valid_0's Score: 0.791584
# [1420]	valid_0's Score: 0.79129
# [1430]	valid_0's Score: 0.791589
# [1440]	valid_0's Score: 0.791886
# [1450]	valid_0's Score: 0.791724
# [1460]	valid_0's Score: 0.791368
# [1470]	valid_0's Score: 0.79139
# [1480]	valid_0's Score: 0.791471
# [1490]	valid_0's Score: 0.791823
# [1500]	valid_0's Score: 0.791765
# [1510]	valid_0's Score: 0.791804
# [1520]	valid_0's Score: 0.79189
# [1530]	valid_0's Score: 0.791572
# [1540]	valid_0's Score: 0.791403
# [1550]	valid_0's Score: 0.791262
# [1560]	valid_0's Score: 0.791492
# [1570]	valid_0's Score: 0.791895
# [1580]	valid_0's Score: 0.791897
# [1590]	valid_0's Score: 0.791873
# [1600]	valid_0's Score: 0.791839
# [1610]	valid_0's Score: 0.791775
# [1620]	valid_0's Score: 0.792262
# [1630]	valid_0's Score: 0.792281
# [1640]	valid_0's Score: 0.79224
# [1650]	valid_0's Score: 0.79207
# [1660]	valid_0's Score: 0.79177
# [1670]	valid_0's Score: 0.792082
# [1680]	valid_0's Score: 0.79221
# [1690]	valid_0's Score: 0.792318
# [1700]	valid_0's Score: 0.79253
# [1710]	valid_0's Score: 0.792595
# [1720]	valid_0's Score: 0.791946
# [1730]	valid_0's Score: 0.792349
# [1740]	valid_0's Score: 0.792432
# [1750]	valid_0's Score: 0.792287
# [1760]	valid_0's Score: 0.792325
# [1770]	valid_0's Score: 0.792182
# [1780]	valid_0's Score: 0.792237
# [1790]	valid_0's Score: 0.792192
# [1800]	valid_0's Score: 0.792089
# [1810]	valid_0's Score: 0.792068
# [1820]	valid_0's Score: 0.792069
# [1830]	valid_0's Score: 0.792443
# [1840]	valid_0's Score: 0.791838
# [1850]	valid_0's Score: 0.791917
# [1860]	valid_0's Score: 0.792083
# [1870]	valid_0's Score: 0.791322
# [1880]	valid_0's Score: 0.79157
# [1890]	valid_0's Score: 0.791508
# [1900]	valid_0's Score: 0.791547
# [1910]	valid_0's Score: 0.791876
# [1920]	valid_0's Score: 0.791965
# [1930]	valid_0's Score: 0.792295
# [1940]	valid_0's Score: 0.792124
# [1950]	valid_0's Score: 0.792232
# [1960]	valid_0's Score: 0.792312
# [1970]	valid_0's Score: 0.792284
# [1980]	valid_0's Score: 0.792433
# [1990]	valid_0's Score: 0.792628
# [2000]	valid_0's Score: 0.792695
# [2010]	valid_0's Score: 0.792617
# [2020]	valid_0's Score: 0.792404
# [2030]	valid_0's Score: 0.792374
# [2040]	valid_0's Score: 0.792183
# [2050]	valid_0's Score: 0.791926
# [2060]	valid_0's Score: 0.791865
# [2070]	valid_0's Score: 0.792075
# [2080]	valid_0's Score: 0.792052
# [2090]	valid_0's Score: 0.792049
# [2100]	valid_0's Score: 0.791798
# [2110]	valid_0's Score: 0.792053
# [2120]	valid_0's Score: 0.791964
# [2130]	valid_0's Score: 0.792029
# [2140]	valid_0's Score: 0.791943
# [2150]	valid_0's Score: 0.791983
# [2160]	valid_0's Score: 0.791918
# [2170]	valid_0's Score: 0.792194
# [2180]	valid_0's Score: 0.791914
# [2190]	valid_0's Score: 0.791869
# [2200]	valid_0's Score: 0.791842
# [2210]	valid_0's Score: 0.791849
# [2220]	valid_0's Score: 0.792078
# [2230]	valid_0's Score: 0.791927
# [2240]	valid_0's Score: 0.79199
# [2250]	valid_0's Score: 0.791777
# [2260]	valid_0's Score: 0.791833
# [2270]	valid_0's Score: 0.791785
# [2280]	valid_0's Score: 0.791572
# [2290]	valid_0's Score: 0.791863
# Early stopping, best iteration is:
# [794]	valid_0's Score: 0.793373
# printing using current round of model..
#
#
#
# Fold 3 | Training Time: 13:06 | Score = 0.79322
#
#
#
# printing using best round of model..
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:859: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
# Fold 3 | Training Time: 13:20 | Score = 0.79316
#
#
#
# #########################
# ### Fold 4
# ### Train size: 367131 , Validation size: 91782
# #########################
# Training until validation scores don't improve for 1500 rounds
# [10]	valid_0's Score: 0.737989
# [20]	valid_0's Score: 0.743564
# [30]	valid_0's Score: 0.748691
# [40]	valid_0's Score: 0.753463
# [50]	valid_0's Score: 0.756248
# [60]	valid_0's Score: 0.759408
# [70]	valid_0's Score: 0.762572
# [80]	valid_0's Score: 0.765062
# [90]	valid_0's Score: 0.767883
# [100]	valid_0's Score: 0.769977
# [110]	valid_0's Score: 0.771957
# [120]	valid_0's Score: 0.7742
# [130]	valid_0's Score: 0.776123
# [140]	valid_0's Score: 0.777537
# [150]	valid_0's Score: 0.778568
# [160]	valid_0's Score: 0.77998
# [170]	valid_0's Score: 0.780969
# [180]	valid_0's Score: 0.782339
# [190]	valid_0's Score: 0.783382
# [200]	valid_0's Score: 0.784626
# [210]	valid_0's Score: 0.785584
# [220]	valid_0's Score: 0.786315
# [230]	valid_0's Score: 0.786979
# [240]	valid_0's Score: 0.787289
# [250]	valid_0's Score: 0.787616
# [260]	valid_0's Score: 0.788327
# [270]	valid_0's Score: 0.788655
# [280]	valid_0's Score: 0.789032
# [290]	valid_0's Score: 0.789547
# [300]	valid_0's Score: 0.78957
# [310]	valid_0's Score: 0.789554
# [320]	valid_0's Score: 0.789739
# [330]	valid_0's Score: 0.790353
# [340]	valid_0's Score: 0.791057
# [350]	valid_0's Score: 0.791246
# [360]	valid_0's Score: 0.791575
# [370]	valid_0's Score: 0.791663
# [380]	valid_0's Score: 0.791964
# [390]	valid_0's Score: 0.791939
# [400]	valid_0's Score: 0.791633
# [410]	valid_0's Score: 0.791805
# [420]	valid_0's Score: 0.791895
# [430]	valid_0's Score: 0.791834
# [440]	valid_0's Score: 0.792428
# [450]	valid_0's Score: 0.792787
# [460]	valid_0's Score: 0.792871
# [470]	valid_0's Score: 0.793033
# [480]	valid_0's Score: 0.793144
# [490]	valid_0's Score: 0.793177
# [500]	valid_0's Score: 0.793466
# [510]	valid_0's Score: 0.794
# [520]	valid_0's Score: 0.794049
# [530]	valid_0's Score: 0.794118
# [540]	valid_0's Score: 0.793705
# [550]	valid_0's Score: 0.794057
# [560]	valid_0's Score: 0.793987
# [570]	valid_0's Score: 0.794057
# [580]	valid_0's Score: 0.794166
# [590]	valid_0's Score: 0.794015
# [600]	valid_0's Score: 0.794455
# [610]	valid_0's Score: 0.794412
# [620]	valid_0's Score: 0.79459
# [630]	valid_0's Score: 0.795011
# [640]	valid_0's Score: 0.794672
# [650]	valid_0's Score: 0.79437
# [660]	valid_0's Score: 0.794289
# [670]	valid_0's Score: 0.794731
# [680]	valid_0's Score: 0.794494
# [690]	valid_0's Score: 0.794971
# [700]	valid_0's Score: 0.795107
# [710]	valid_0's Score: 0.795144
# [720]	valid_0's Score: 0.794952
# [730]	valid_0's Score: 0.79542
# [740]	valid_0's Score: 0.795896
# [750]	valid_0's Score: 0.796074
# [760]	valid_0's Score: 0.796041
# [770]	valid_0's Score: 0.796429
# [780]	valid_0's Score: 0.796457
# [790]	valid_0's Score: 0.796124
# [800]	valid_0's Score: 0.796158
# [810]	valid_0's Score: 0.7963
# [820]	valid_0's Score: 0.796389
# [830]	valid_0's Score: 0.796188
# [840]	valid_0's Score: 0.796634
# [850]	valid_0's Score: 0.796593
# [860]	valid_0's Score: 0.796688
# [870]	valid_0's Score: 0.796696
# [880]	valid_0's Score: 0.796931
# [890]	valid_0's Score: 0.797068
# [900]	valid_0's Score: 0.796759
# [910]	valid_0's Score: 0.796664
# [920]	valid_0's Score: 0.796674
# [930]	valid_0's Score: 0.79689
# [940]	valid_0's Score: 0.79721
# [950]	valid_0's Score: 0.797066
# [960]	valid_0's Score: 0.797031
# [970]	valid_0's Score: 0.797276
# [980]	valid_0's Score: 0.797592
# [990]	valid_0's Score: 0.797369
# [1000]	valid_0's Score: 0.797355
# [1010]	valid_0's Score: 0.797178
# [1020]	valid_0's Score: 0.797243
# [1030]	valid_0's Score: 0.797227
# [1040]	valid_0's Score: 0.797104
# [1050]	valid_0's Score: 0.796983
# [1060]	valid_0's Score: 0.797079
# [1070]	valid_0's Score: 0.797174
# [1080]	valid_0's Score: 0.797368
# [1090]	valid_0's Score: 0.797562
# [1100]	valid_0's Score: 0.796995
# [1110]	valid_0's Score: 0.797274
# [1120]	valid_0's Score: 0.797088
# [1130]	valid_0's Score: 0.79686
# [1140]	valid_0's Score: 0.797184
# [1150]	valid_0's Score: 0.797608
# [1160]	valid_0's Score: 0.79694
# [1170]	valid_0's Score: 0.797515
# [1180]	valid_0's Score: 0.797414
# [1190]	valid_0's Score: 0.797248
# [1200]	valid_0's Score: 0.796973
# [1210]	valid_0's Score: 0.797433
# [1220]	valid_0's Score: 0.797232
# [1230]	valid_0's Score: 0.797237
# [1240]	valid_0's Score: 0.797494
# [1250]	valid_0's Score: 0.796994
# [1260]	valid_0's Score: 0.796743
# [1270]	valid_0's Score: 0.796639
# [1280]	valid_0's Score: 0.796723
# [1290]	valid_0's Score: 0.796744
# [1300]	valid_0's Score: 0.796617
# [1310]	valid_0's Score: 0.796845
# [1320]	valid_0's Score: 0.796808
# [1330]	valid_0's Score: 0.796805
# [1340]	valid_0's Score: 0.79672
# [1350]	valid_0's Score: 0.796657
# [1360]	valid_0's Score: 0.797156
# [1370]	valid_0's Score: 0.796814
# [1380]	valid_0's Score: 0.796627
# [1390]	valid_0's Score: 0.796568
# [1400]	valid_0's Score: 0.796815
# [1410]	valid_0's Score: 0.796865
# [1420]	valid_0's Score: 0.79683
# [1430]	valid_0's Score: 0.79706
# [1440]	valid_0's Score: 0.796889
# [1450]	valid_0's Score: 0.796401
# [1460]	valid_0's Score: 0.796084
# [1470]	valid_0's Score: 0.796217
# [1480]	valid_0's Score: 0.796465
# [1490]	valid_0's Score: 0.79619
# [1500]	valid_0's Score: 0.796335
# [1510]	valid_0's Score: 0.796013
# [1520]	valid_0's Score: 0.796252
# [1530]	valid_0's Score: 0.796489
# [1540]	valid_0's Score: 0.796448
# [1550]	valid_0's Score: 0.796554
# [1560]	valid_0's Score: 0.796533
# [1570]	valid_0's Score: 0.796632
# [1580]	valid_0's Score: 0.79684
# [1590]	valid_0's Score: 0.796821
# [1600]	valid_0's Score: 0.796751
# [1610]	valid_0's Score: 0.796745
# [1620]	valid_0's Score: 0.79647
# [1630]	valid_0's Score: 0.796617
# [1640]	valid_0's Score: 0.796425
# [1650]	valid_0's Score: 0.796108
# [1660]	valid_0's Score: 0.79639
# [1670]	valid_0's Score: 0.796263
# [1680]	valid_0's Score: 0.796325
# [1690]	valid_0's Score: 0.796138
# [1700]	valid_0's Score: 0.796048
# [1710]	valid_0's Score: 0.796093
# [1720]	valid_0's Score: 0.796659
# [1730]	valid_0's Score: 0.796258
# [1740]	valid_0's Score: 0.796281
# [1750]	valid_0's Score: 0.796365
# [1760]	valid_0's Score: 0.79628
# [1770]	valid_0's Score: 0.796514
# [1780]	valid_0's Score: 0.796391
# [1790]	valid_0's Score: 0.796518
# [1800]	valid_0's Score: 0.796309
# [1810]	valid_0's Score: 0.796661
# [1820]	valid_0's Score: 0.796367
# [1830]	valid_0's Score: 0.796343
# [1840]	valid_0's Score: 0.796389
# [1850]	valid_0's Score: 0.796352
# [1860]	valid_0's Score: 0.796075
# [1870]	valid_0's Score: 0.796388
# [1880]	valid_0's Score: 0.796383
# [1890]	valid_0's Score: 0.796204
# [1900]	valid_0's Score: 0.7961
# [1910]	valid_0's Score: 0.795824
# [1920]	valid_0's Score: 0.795842
# [1930]	valid_0's Score: 0.796025
# [1940]	valid_0's Score: 0.795873
# [1950]	valid_0's Score: 0.79608
# [1960]	valid_0's Score: 0.796016
# [1970]	valid_0's Score: 0.796223
# [1980]	valid_0's Score: 0.795922
# [1990]	valid_0's Score: 0.796179
# [2000]	valid_0's Score: 0.796328
# [2010]	valid_0's Score: 0.79616
# [2020]	valid_0's Score: 0.796262
# [2030]	valid_0's Score: 0.795931
# [2040]	valid_0's Score: 0.796098
# [2050]	valid_0's Score: 0.796416
# [2060]	valid_0's Score: 0.79625
# [2070]	valid_0's Score: 0.796186
# [2080]	valid_0's Score: 0.796044
# [2090]	valid_0's Score: 0.795932
# [2100]	valid_0's Score: 0.795972
# [2110]	valid_0's Score: 0.79593
# [2120]	valid_0's Score: 0.795514
# [2130]	valid_0's Score: 0.79553
# [2140]	valid_0's Score: 0.795915
# [2150]	valid_0's Score: 0.795893
# [2160]	valid_0's Score: 0.795788
# [2170]	valid_0's Score: 0.795676
# [2180]	valid_0's Score: 0.795839
# [2190]	valid_0's Score: 0.795824
# [2200]	valid_0's Score: 0.795879
# [2210]	valid_0's Score: 0.795816
# [2220]	valid_0's Score: 0.795858
# [2230]	valid_0's Score: 0.795981
# [2240]	valid_0's Score: 0.795913
# [2250]	valid_0's Score: 0.79608
# [2260]	valid_0's Score: 0.796119
# [2270]	valid_0's Score: 0.795972
# [2280]	valid_0's Score: 0.796222
# [2290]	valid_0's Score: 0.796013
# [2300]	valid_0's Score: 0.795946
# [2310]	valid_0's Score: 0.795963
# [2320]	valid_0's Score: 0.796297
# [2330]	valid_0's Score: 0.795919
# [2340]	valid_0's Score: 0.796172
# [2350]	valid_0's Score: 0.795915
# [2360]	valid_0's Score: 0.79587
# [2370]	valid_0's Score: 0.795931
# [2380]	valid_0's Score: 0.795802
# [2390]	valid_0's Score: 0.795465
# [2400]	valid_0's Score: 0.795523
# [2410]	valid_0's Score: 0.795726
# [2420]	valid_0's Score: 0.795433
# [2430]	valid_0's Score: 0.795372
# [2440]	valid_0's Score: 0.79541
# [2450]	valid_0's Score: 0.795285
# [2460]	valid_0's Score: 0.795028
# [2470]	valid_0's Score: 0.795021
# [2480]	valid_0's Score: 0.794726
# [2490]	valid_0's Score: 0.794893
# Early stopping, best iteration is:
# [994]	valid_0's Score: 0.797666
# printing using current round of model..
#
#
#
# Fold 4 | Training Time: 14:17 | Score = 0.79745
#
#
#
# printing using best round of model..
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:859: UserWarning: Converting data to scipy sparse matrix.
#   _log_warning('Converting data to scipy sparse matrix.')
# Fold 4 | Training Time: 14:33 | Score = 0.79737
#
#
#
#
#
#
# Score: 0.79402
